# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# testing
# !mkdir -p /content/local_data/test
# !cp /content/drive/MyDrive/Argoverse_Project/data/forecasting_test_v1.1.tar.gz /content/local_data/
# !tar -xzf /content/local_data/forecasting_test_v1.1.tar.gz -C /content/local_data/test --strip-components=1

# %%
import os
import pandas as pd
import torch
from tqdm import tqdm
from data_loader import load_sequence

def pre_process_dataset(source_folder, output_folder):
    os.makedirs(output_folder, exist_ok=True)
    files = [f for f in os.listdir(source_folder) if f.endswith('.csv')]
    print(f"Converting {len(files)} files from {source_folder} to binary tensors...")
    num_files = 0
    for f in tqdm(files):
        file_path = os.path.join(source_folder, f)
        data = load_sequence(file_path)
        if data is not None:
            num_files += 1
            past, future, origin, theta = data
            # print(num_files, len(future))
            # Package them into a single dictionary tensor
            payload = {
                'past': torch.tensor(past, dtype=torch.float32),
                'future': torch.tensor(future, dtype=torch.float32),
                'origin': torch.tensor(origin, dtype=torch.float32),
                'theta': torch.tensor(theta, dtype=torch.float32)
            }
            # Save as binary file
            output_path = os.path.join(output_folder, f.replace('.csv', '.pt'))
            torch.save(payload, output_path)

# Convert both splits on Colab's fast scratch disk
pre_process_dataset("/content/local_data/test/data", "/content/tensor_data/test")
# Out:
# Converting 78143 files from /content/local_data/test/data to binary tensors...
#  48%|████▊     | 37303/78143 [01:36<02:23, 284.45it/s]

# %%
os.chdir('/content/drive/MyDrive/Argoverse_Project/scripts')

# %%
# !python test_and_visualize.py
# Out:
# Loading validation dataset for evaluation...
# 78143
# Loading trained LSTM weights...
# Generating trajectory plots...
# 🖼️ Saved visualization plot to: ../plots/sample_1.png
# 🖼️ Saved visualization plot to: ../plots/sample_2.png
# 🖼️ Saved visualization plot to: ../plots/sample_3.png
# 🖼️ Saved visualization plot to: ../plots/sample_4.png
# 🖼️ Saved visualization plot to: ../plots/sample_5.png
# 🖼️ Saved visualization plot to: ../plots/sample_6.png
# 🖼️ Saved visualization plot to: ../plots/sample_7.png
# 🖼️ Saved visualization plot to: ../plots/sample_8.png
# 🖼️ Saved visualization plot to: ../plots/sample_9.png
# 🖼️ Saved visualization plot to: ../plots/sample_10.png
# 🖼️ Saved visualization plot to: ../plots/sample_11.png
# 🖼️ Saved visualization plot to: ../plots/sample_12.png
# 🖼️ Saved visualization plot to: ../plots/sample_13.png
# 🖼️ Saved visualization plot to: ../plots/sample_14.png
# 🖼️ Saved visualization plot to: ../plots/sample_15.png
# ...

# %%
import os
import getpass

# 1. Move into your project directory where your code lives
# %cd /content/drive/MyDrive/Argoverse_Project/scripts
# Out:
# /content/drive/MyDrive/Argoverse_Project/scripts

# %%
# 2. Tell Git who you are
# !git config --global user.email "ramkumarkaruna@gmail.com"
# !git config --global user.name "itzram01"

# %%
# 3. Create a .gitignore file so Git NEVER uploads your heavy data files
with open(".gitignore", "w") as f:
    f.write("*.pt\n*.tar.gz\n*.csv\n__pycache__/\n.ipynb_checkpoints/\n")
print("✅ .gitignore created successfully! Data files will be safely bypassed.")
# Out:
# ✅ .gitignore created successfully! Data files will be safely bypassed.

# %%
# 4. Initialize a clean local Git repository
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/Argoverse_Project/scripts/.git/

# %%
# 5. Securely input your GitHub token (paste your token when the prompt appears)
git_token = getpass.getpass("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")
username = "itzram01"
repo_name = "Argoverse-Trajectory-Prediction-LSTM"
# Out:
# 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··········

# %%
# 6. Link your local directory to your remote GitHub repository
# If you get a "remote origin already exists" error, uncomment the line below and re-run:
# !git remote remove origin
# !git remote add origin https://{git_token}@github.com/{username}/{repo_name}.git

# %%
# 7. Stage all your script files and your new README
# !git add .

# 8. Create your first save state (Commit)
# !git commit -m "Phase 1: Initial baseline LSTM trajectory prediction pipeline"


# 1. Rename your current local branch from 'master' to 'main'
# !git branch -m main

# 2. Push your code using 'main' instead of 'master'
# !git push -u origin main
